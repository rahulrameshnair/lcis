# %% [markdown]
# # LCIS Network Export
#
# This notebook exports a Brightway database network as GraphML using the installed `lcis` package.

# %%
from pathlib import Path

from lcis.inventory import export_network

# %% [markdown]
# ## Network settings

# %%
project_name = input("Enter the Brightway project name: ")
database_name = input("Enter the Brightway database name: ")
output_path = Path(input(f"Enter GraphML output path [{database_name}.graphml]: ") or f"{database_name}.graphml")

# %% [markdown]
# ## Run network export

# %%
graphml_path = export_network(
    project_name=project_name,
    database_name=database_name,
    output_path=output_path,
)

graphml_path
